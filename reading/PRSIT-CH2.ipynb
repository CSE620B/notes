# %% [markdown]
# # Introduction

# %% [markdown]
# ![image.png](attachment:b3d0df60-bff9-4e72-9c40-19cc641c2095.png)
# > Figure 2.1 :
# A remote
# sensing sensor measures
# reflected or emitted en-
# ergy. An active sensor has
# its own source of energy.

# %% [markdown]
# ## EM Energy

# %% [markdown]
# ### Waves and Photons

# %% [markdown]
# THere is a particle model and a wave model of EM Energy.
# Electric and MAgnetic waves are perpendicular to each other.

# %% [markdown]
# ![image.png](attachment:099897bc-e42a-44cf-a01b-34f1792f1a41.png)
# > Figure 2.2 : Electric (E)
# and magnetic (M) vec-
# tors of an electromagnetic
# wave.

# %% [markdown]
# Wavelength:  $\lambda$  measured in meters

# %% [markdown]
# Frequency: $v$   measured in Hz (hertz)

# %% [markdown]
# The speped of light is related to these:
# $$c = \lambda \times v$$
# So...
# $$ \frac{c}{\lambda} = v$$
# there is an inverse relationship

# %% [markdown]
# ![image.png](attachment:e0ade374-ba52-40e9-a744-5bc9d6a3530d.png)
# > Figure 2.3 : Relationship
# between wavelength, fre-
# quency and energy.

# %% [markdown]
# "Photon" is a prtical model of light energy.

# %% [markdown]
# photon: $J$
# photon energy: $Q$
# Planclk's constant: $h$

# %% [markdown]
# $$h=6.6262\cdot 10^{-34} J s$$

# %% [markdown]
# Equation 2.2:
#     $$Q = h \times v = h \times\frac{c}{\lambda}$$

# %% [markdown]
# Takeaway:
#  - Longer wavelength $\lambda$ ==> lower energy
#  - Therefore they are harder to measure...
#  - Gamma waves is high energy, radio waves are low energy

# %% [markdown]
# ### Sources of EM Energy

# %% [markdown]
# *blackbody* -->   hot things radiate energy

# %% [markdown]
# Emissivity: $\epsilon$  is energy emmitted by an object

# %% [markdown]
# Absorptivity: $\alpha$ is energy absorbed

# %% [markdown]
# The scope of BB model is limited o $\alpha = \epsilon = 1$, not most real objects

# %% [markdown]
# ![image.png](attachment:a8c2019c-6503-4cdd-acdb-330334fdcdca.png)
# > Blackbody radiation curves based on Stefan-Boltzmann’s law (with temperatures, T , in
# K).

# %% [markdown]
# Usually $\epsilon < 1$, e.g. $0.8 \leq \epsilon \leq 0.9$.

# %% [markdown]
# ### EM Spectrum

# %% [markdown]
# ![image.png](attachment:09f85922-4815-4248-9b78-16851a0d7c1a.png)
# > Figure 2.5 : The electromagnetic spectrum, after [23].

# %% [markdown]
# ### Active and Passive RS

# %% [markdown]
# ## Energy interactionin the atmosphere

# %% [markdown]
# ### Absorption and Transmission

# %% [markdown]
# ![image.png](attachment:66593738-dad5-4697-9a9b-d426c724a095.png)
# > Figure 2.6 : Energy interactions in the atmosphere and at the surface.

# %% [markdown]
# ![image.png](attachment:cca6bca2-c9b4-4434-a8ac-7888e8ed1123.png)
# > Figure 2.7 : Atmospheric transmission expressed as percentage.

# %% [markdown]
# ![image.png](attachment:ada367db-5ceb-4819-9100-bfc1d762e5dc.png)
# > Figure 2.8 : The electro-
# magnetic spectrum of the
# Sun as observed with and
# without the influence of
# the Earth’s atmosphere.
#
# The relative dips in this curve indicate the absorption by different gases in the atmosphere.

# %% [markdown]
# ### Atmospheric Scattering

# %% [markdown]
# **Rayleigh Scattering**  (<)

# %% [markdown]
# ![image.png](attachment:ed7696eb-d392-4dbe-a854-900b404e19ab.png)
# > Figure 2.9 : Rayleigh scattering is caused by particles smaller than the
# wavelength and is maximal for small wavelengths.

# %% [markdown]
# ![image.png](attachment:45a80677-96ab-465b-a173-b8871cd7a429.png)
# > Figure 2.10 : Rayleigh scattering causes us to perceive a blue sky during
# daytime and a red sky at sunset.

# %% [markdown]
# **Mie Scattering** (=)
#
# E.g. aerosols
#
# Overcast

# %% [markdown]
# **Non-Selective Scattering** (>)

# %% [markdown]
# ![image.png](attachment:e54a51f3-4968-4cc4-8765-6bd87b8c63eb.png)
# > Figure 2.11 : Direct and indirect effects of clouds in optical remote sensing.

# %% [markdown]
# ## Energy Interactions with the Earth's Surface

# %% [markdown]
# - reflection
# - absorption
# - transmission

# %% [markdown]
# - Specular Reflection
#   Mirror, shine
# - Diffuse Reflection
#   Shadine (bright facing light, dark away)

# %% [markdown]
# ![image.png](attachment:0e4719e3-eeef-47ce-ab7a-3ed0ac46ea81.png)
# > Figure 2.12 : Schematic diagrams showing(a) specular and (b) diffuse reflection.

# %% [markdown]
# ### Spectral reflectance curves
# - Irradiance
#   Energy reaching the surface (per sq m)
# - Radiance
#   Energy reflected from the surface in a given direction (perm sq m, per steradian)

# %% [markdown]
# - Spectral radiance distribution functions (SPDF) libraries can be matched to different materials

# %% [markdown]
# **Vegetation**

# %% [markdown]
# ![image.png](attachment:144243a0-77f0-48cc-9e90-ea922f676ad4.png)
# > Figure 2.13 : An idealized spectral reflectance curve of a healthy vegetation.

# %% [markdown]
# Look up "NDVI"  (normalized XXX vegetation index)

# %% [markdown]
# **Bare Soil**
#
# Dips in the plot are caused by water content.
#
# ![image.png](attachment:f5942a00-6213-4b40-89ff-c74c14abca6e.png)
# > Figure 2.14 : Reflectance
# spectra of surface samples of five mineral soils,
# (a) organic dominated,
# (b) minimally altered,
# (c) iron altered, (d) organic affected and (e) iron
# dominated (from [24]).

# %% [markdown]
# **Water**

# %% [markdown]
# ![image.png](attachment:6412f258-012c-4b05-9623-5ddd5e6b4782.png)
# > Figure 2.15 : Typical effects of chlorophyll and sediments on water reflectance:
# (a) ocean water, (b) turbid water, (c) water with chlorophyll (from [24].)

# %% [markdown]
# # Questions

# %% [markdown]
# The following questions can help you to study Chapter 2.
# 1. What are advantages/disadvantages of aerial RS compared to spaceborne
# RS in terms of atmospheric disturbance?
# 2. How important are laboratory spectra in understanding the remote sens-
# ing images?

# %% [markdown]
# These are typical exam questions:
# 1. List and describe the two models used to describe electromagnetic energy.
# 2. How are wavelength and frequency related to each other (give a formula)?
# 3. What is the electromagnetic spectrum?
# 4. List and define the three types of atmospheric scattering?
# 5. What specific energy interactions take place when EM energy from the Sun
# hits the Earth’s surface?
# 6. In your own words give a definition of an atmospheric window.
# 7. Indicate True or False: Only the wavelength region outside the main ab-
# sorption bands of the atmospheric gases can be used for remote sensing.
# 8. Indicate True or False: The amount of energy detected by a remote sensing
# sensor is a function of how energy is partitioned between its source and
# the materials with which it interacts on its way to the detector.
